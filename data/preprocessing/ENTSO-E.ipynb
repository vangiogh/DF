# %%
path = '../raw/energy_europe_price.csv'

# %%
import pandas as pd

# %%
df = pd.read_csv(path, index_col=0)

# %%
df.index = pd.to_datetime(df.index)

# %%
pd.read_csv(path, index_col=0, parse_dates=True)
# Out:
#                               AT     BE     BG     HR     CZ  DE_LU   DK_1  \
# 2020-01-01 00:00:00+00:00  38.60  38.60  68.57  38.60  30.40  38.60  31.77
# 2020-01-01 01:00:00+00:00  36.55  36.55  58.99  36.55  28.53  36.55  31.57
# ...                          ...    ...    ...    ...    ...    ...    ...
# 2023-12-31 22:00:00+00:00   9.35   3.17  14.95  12.45   7.44   2.44  26.87
# 2023-12-31 23:00:00+00:00   0.10   0.10   0.10   0.10   0.10   0.10  16.99
#
#                               EE     FI      MK  ...     PL     PT      RO  \
# 2020-01-01 00:00:00+00:00  28.45  28.45     NaN  ...  34.67  38.60  145.27
# 2020-01-01 01:00:00+00:00  27.90  27.90     NaN  ...  33.30  36.55  136.33
# ...                          ...    ...     ...  ...    ...    ...     ...
# 2023-12-31 22:00:00+00:00  40.01  40.01   82.65  ...  35.70  71.96   14.95
# 2023-12-31 23:00:00+00:00  38.37  38.37  105.14  ...  76.69  63.33    0.10
#
# ...

# %%
df = pd.read_parquet('../raw/energy_spain_generation_years_ts.parquet')

# %%
df.index.name = 'datetime'

# %%
df.to_csv('../raw/energy_spain_generation_years_ts.csv')
