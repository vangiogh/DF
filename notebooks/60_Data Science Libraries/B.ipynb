# %% [markdown]
# # Python libraries for data science

# %% [markdown]
# [**See `libraries` instructions**](https://datons.craft.me/h3f5pSQSE7l6RW) to complete the following exercises.

# %% [markdown]
# ## Numerical operations: `numpy`
#
# https://numpy.org/doc/stable/reference/random/index.html

# %%
import numpy as np

# %%
salary_madrid = np.random.normal(25, 3, 100)
salary_barcelona = 1.2 * salary_madrid + np.random.normal(0, 2, 100)

# %% [markdown]
# ## Graphs and plots: `plotly`
#
# https://plotly.com/python/plotly-express/

# %%
import plotly.express as px

# %% [markdown]
# ### Line plot

# %%
px.line(x=salary_madrid, y=salary_barcelona)

# %% [markdown]
# ### Density contour plot

# %%
px.density_contour(x=salary_madrid, y=salary_barcelona)

# %% [markdown]
# ### Maps

# %%
import plotly.express as px

df = px.data.election()
geojson = px.data.election_geojson()

fig = px.choropleth_mapbox(df, geojson=geojson, color="Bergeron",
                           locations="district", featureidkey="properties.district",
                           center={"lat": 45.5517, "lon": -73.7073},
                           mapbox_style="carto-positron", zoom=9)

fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()

# %% [markdown]
# ### Scatter plot

# %%
px.scatter(x=salary_madrid, y=salary_barcelona)

# %% [markdown]
# ## Data tables: `pandas`
#
# https://pandas.pydata.org/docs/getting_started/

# %%
import pandas as pd

# %% [markdown]
# ### From scratch

# %%
pd.DataFrame({'x':salary_madrid, 'y':salary_barcelona})
# Out:
#             x          y
# 0   21.378498  22.993528
# 1   22.316311  28.209843
# ..        ...        ...
# 98  23.188746  27.594518
# 99  28.691030  38.087502
#
# [100 rows x 2 columns]

# %% [markdown]
# ### Excel

# %%
pd.read_excel('data/russia-world-cup.xlsx')
# Out:
#             Team  Games Played  Wins  Draws  Losses  Points Accumulated  \
# 0      Argentina             4     1      1       2                   4
# 1      Australia             3     0      1       2                   1
# 2        Belgium             7     6      0       1                  18
# 3         Brazil             5     3      1       1                  10
# 4       Colombia             4     2      1       1                   7
# 5     Costa Rica             3     0      1       2                   1
# 6        Croatia             7     4      2       1                  14
# 7        Denmark             4     1      3       0                   6
# 8          Egypt             3     0      0       3                   0
# 9        England             7     3      1       3                  10
# 10        France             7     6      1       0                  19
# 11       Germany             3     1      0       2                   3
# ...

# %% [markdown]
# ### CSV

# %%
pd.read_csv('data/best_tennis_players_stats.csv')
# Out:
#   player  income  titles  grand slams  turned professional  wins  losses
# 0  roger     130     103           20                 1998  1251     275
# 1   rafa     127      90           21                 2001  1038     209
# 2   nole     154      86           20                 2003   989     199

# %% [markdown]
# ### HTML

# %%
url = 'https://www.skysports.com/la-liga-table'
df = pd.read_html(url)[0]

# %%
df
# Out:
#      #             Team  Pl   W   D   L   F   A  GD  Pts  Last 6
# 0    1      Real Madrid  30  23   6   1  66  20  46   75     NaN
# 1    2        Barcelona  30  20   7   3  61  34  27   67     NaN
# 2    3           Girona  30  20   5   5  62  36  26   65     NaN
# 3    4  Atletico Madrid  30  18   4   8  56  35  21   58     NaN
# 4    5  Athletic Bilbao  30  16   8   6  50  28  22   56     NaN
# 5    6    Real Sociedad  30  13  10   7  43  31  12   49     NaN
# 6    7         Valencia  30  12   8  10  33  32   1   44     NaN
# 7    8       Real Betis  30  10  12   8  36  36   0   42     NaN
# 8    9          Osasuna  30  11   6  13  36  43  -7   39     NaN
# 9   10       Villarreal  30  10   8  12  48  53  -5   38     NaN
# 10  11           Getafe  30   9  11  10  37  43  -6   38     NaN
# 11  12       Las Palmas  30  10   7  13  29  33  -4   37     NaN
# 12  13           Alaves  30   8   8  14  26  36 -10   32     NaN
# ...

# %% [markdown]
# ### Combine libraries

# %%
df.plot(x='F', y='Pts', kind='scatter');

# %%
px.scatter(df, x='F', y='Pts', hover_name='Team')

# %%
px.scatter(df, x='F', y='Pts', hover_name='Team', trendline='ols')

# %% [markdown]
# ## Machine Learning: `sklearn`
#
# https://scikit-learn.org/stable/user_guide.html

# %% [markdown]
# ### Linear regression

# %%
from sklearn.linear_model import LinearRegression

explanatory = df[['F']]
target = df['Pts']

model = LinearRegression()
model.fit(explanatory, target)
# Out:
# LinearRegression()

# %%
df_pred = df[['F', 'Pts']].copy()
df_pred['Pts_pred_lr'] = model.predict(explanatory)
df_pred
# Out:
#      F  Pts  Pts_pred_lr
# 0   66   75    70.182354
# 1   61   67    64.693977
# 2   62   65    65.791652
# 3   56   58    59.205599
# 4   50   56    52.619546
# 5   43   49    44.935818
# 6   33   44    33.959063
# 7   36   42    37.252090
# 8   36   39    37.252090
# 9   48   38    50.424195
# 10  37   38    38.349765
# 11  29   37    29.568362
# 12  26   32    26.275335
# 13  37   31    38.349765
# 14  25   31    25.177660
# 15  25   30    25.177660
# 16  32   28    32.861388
# 17  21   25    20.786958
# 18  30   14    30.666037
# 19  28   13    28.470686

# %%
import matplotlib.pyplot as plt

plt.scatter(df['F'], df['Pts'], label='Observed data')
plt.plot(df['F'], df_pred['Pts_pred_lr'], color='orange', label='Prediction: Linear Regression', marker='o')
plt.legend()

# %% [markdown]
# ### Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor

explanatory = df[['F']]
target = df['Pts']

model = DecisionTreeRegressor()
model.fit(explanatory, target)
# Out:
# DecisionTreeRegressor()

# %%
df_pred['Pts_pred_dt'] = model.predict(explanatory)
df_pred
# Out:
#      F  Pts  Pts_pred_lr  Pts_pred_dt
# 0   66   75    70.182354         75.0
# 1   61   67    64.693977         67.0
# 2   62   65    65.791652         65.0
# 3   56   58    59.205599         58.0
# 4   50   56    52.619546         56.0
# 5   43   49    44.935818         49.0
# 6   33   44    33.959063         44.0
# 7   36   42    37.252090         40.5
# 8   36   39    37.252090         40.5
# 9   48   38    50.424195         38.0
# 10  37   38    38.349765         34.5
# 11  29   37    29.568362         37.0
# 12  26   32    26.275335         32.0
# 13  37   31    38.349765         34.5
# 14  25   31    25.177660         30.5
# 15  25   30    25.177660         30.5
# 16  32   28    32.861388         28.0
# 17  21   25    20.786958         25.0
# 18  30   14    30.666037         14.0
# 19  28   13    28.470686         13.0

# %%
import matplotlib.pyplot as plt

plt.scatter(df['F'], df['Pts'], label='Observed data')
plt.plot(df['F'], df_pred['Pts_pred_lr'], color='orange', label='Prediction: Linear Regression', marker='o')
plt.scatter(df['F'], df_pred['Pts_pred_dt'], color='green', label='Prediction: Decision Tree')
plt.legend();

# %%
from sklearn.tree import plot_tree

plot_tree(model, feature_names=['F'], filled=True, rounded=True, fontsize=8, max_depth=2);
