# %%
url = 'http://ergast.com/api/f1/drivers.json'

# %%
import requests

response = requests.get(url)

# %%
data = response.json()

# %%
import pandas as pd

# %%
pd.DataFrame(data['MRData']['DriverTable']['Drivers']).style
# Out:
# <style type="text/css">
# </style>
# <table id="T_c625c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c625c_level0_col0" class="col_heading level0 col0" >driverId</th>
#       <th id="T_c625c_level0_col1" class="col_heading level0 col1" >url</th>
#       <th id="T_c625c_level0_col2" class="col_heading level0 col2" >givenName</th>
#       <th id="T_c625c_level0_col3" class="col_heading level0 col3" >familyName</th>
#       <th id="T_c625c_level0_col4" class="col_heading level0 col4" >dateOfBirth</th>
#       <th id="T_c625c_level0_col5" class="col_heading level0 col5" >nationality</th>
#       <th id="T_c625c_level0_col6" class="col_heading level0 col6" >permanentNumber</th>
#       <th id="T_c625c_level0_col7" class="col_heading level0 col7" >code</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c625c_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
da

# %%
import pandas as pd
