# %% [markdown]
# # Self study data visualization in Python

# %% [markdown]
# - [Matplotlib](https://matplotlib.org/)
# - [Seaborn](https://seaborn.pydata.org/)
# - [Plotly](https://plotly.com/python/)

# %% [markdown]
# ## Pick up an example
#
# - For example, this one: https://plotly.com/python/bar-charts/

# %%
# Out:
#     country continent  year  lifeExp       pop    gdpPercap iso_alpha  iso_num
# 240  Canada  Americas  1952   68.750  14785584  11367.16112       CAN      124
# 241  Canada  Americas  1957   69.960  17010154  12489.95006       CAN      124
# ..      ...       ...   ...      ...       ...          ...       ...      ...
# 250  Canada  Americas  2002   79.770  31902268  33328.96507       CAN      124
# 251  Canada  Americas  2007   80.653  33390141  36319.23501       CAN      124
#
# [12 rows x 8 columns]

# %% [markdown]
# ## Replicate it with another dataset
#
# ### From the library

# %% [markdown]
# ### From your industry
#
# - [APIs](https://datons.ai/tag/api/)
# - [Kaggle](https://www.kaggle.com/)

# %%
# Out:
#                  TYPE        DATE START TIME END TIME  USAGE UNITS    COST  \
# 0      Electric usage  10/22/2016       0:00     0:14   0.01   kWh  $0.00
# 1      Electric usage  10/22/2016       0:15     0:29   0.01   kWh  $0.00
# ...               ...         ...        ...      ...    ...   ...     ...
# 70366  Electric usage  10/24/2018      23:30    23:44   0.03   kWh  $0.01
# 70367  Electric usage  10/24/2018      23:45    23:59   0.03   kWh  $0.01
#
#        NOTES
# 0        NaN
# 1        NaN
# ...      ...
# 70366    NaN
# 70367    NaN
#
# [70368 rows x 8 columns]
