# %% [markdown]
# ## FILTRAR LOS DATOS DE LA LIBRERIA "PANDA" CON MÁSCARAS EN MATRICES:

# %% [markdown]
# ## DATOS

# %%
import pandas as pd

# %%
df = pd.read_csv('data/gapminder.csv',index_col=0)

# %% [markdown]
# **PREGUNTA: No entiendo porque hay que introducir una columna como índice, si realmente no te lo está pidiendo el ejercicio.**
#
# Por otro lado, entiendo que la definición de la variables, da igual que usemos las que utiliza el profesor como cualquier otras,
# mientras se entienda que hacen referencia al ejercicio solicitado.

# %%
df
# Out:
#                    continent  year  lifeExp       pop     gdpPercap iso_alpha  \
# country
# Afghanistan             Asia  2007   43.828  31889923    974.580338       AFG
# Albania               Europe  2007   76.423   3600523   5937.029526       ALB
# Algeria               Africa  2007   72.301  33333216   6223.367465       DZA
# Angola                Africa  2007   42.731  12420476   4797.231267       AGO
# Argentina           Americas  2007   75.320  40301927  12779.379640       ARG
# ...                      ...   ...      ...       ...           ...       ...
# Vietnam                 Asia  2007   74.249  85262356   2441.576404       VNM
# West Bank and Gaza      Asia  2007   73.422   4018332   3025.349798       PSE
# Yemen, Rep.             Asia  2007   62.698  22211743   2280.769906       YEM
# Zambia                Africa  2007   42.384  11746035   1271.211593       ZMB
# Zimbabwe              Africa  2007   43.487  12311143    469.709298       ZWE
#
# ...

# %% [markdown]
# A continuación creamos una variable en la que filtrará sobre la tabla los valores en la columna Continent, y le asignaremos el valor 'Asia" para ello utilizaremos 2 signo iguales.

# %% [markdown]
# ## CONDICIONAL SIMPLE

# %% [markdown]
# ## Crear una máscara:
#       mascara también es una variable
#       mascara = variable['columna'] == 'ValorDeLaColumna'

# %%
df_countries = df['continent'] == 'Asia'

# %%
df_countries
# Out:
# country
# Afghanistan            True
# Albania               False
# Algeria               False
# Angola                False
# Argentina             False
#                       ...
# Vietnam                True
# West Bank and Gaza     True
# Yemen, Rep.            True
# Zambia                False
# Zimbabwe              False
# Name: continent, Length: 142, dtype: bool

# %% [markdown]
# Ahora cogemos la primera variable que era df y le añadimos a continuación la variable filtro_asia entre corchetes para que filtre sobre la tabla el valor 'Asia'

# %% [markdown]
# ## FILTRAR DATOS CON MASK

# %% [markdown]
# Con el siguiente filtro, filtramos la variables df con el filtro_asia, por lo que cuando se muestren los datos, solo tendrían que aparecer los datos que estén dentro del continente de "Asia".

# %%
df[df_countries]
# Out:
#                    continent  year  lifeExp         pop     gdpPercap  \
# country
# Afghanistan             Asia  2007   43.828    31889923    974.580338
# Bahrain                 Asia  2007   75.635      708573  29796.048340
# Bangladesh              Asia  2007   64.062   150448339   1391.253792
# Cambodia                Asia  2007   59.723    14131858   1713.778686
# China                   Asia  2007   72.961  1318683096   4959.114854
# Hong Kong, China        Asia  2007   82.208     6980412  39724.978670
# India                   Asia  2007   64.698  1110396331   2452.210407
# Indonesia               Asia  2007   70.650   223547000   3540.651564
# Iran                    Asia  2007   70.964    69453570  11605.714490
# Iraq                    Asia  2007   59.545    27499638   4471.061906
# Israel                  Asia  2007   80.745     6426679  25523.277100
# Japan                   Asia  2007   82.603   127467972  31656.068060
# ...

# %% [markdown]
# ## NUMÉRICO (ESTO NO ME FUNCIONA Y NO SE VISUALIZAR EL ERROR)

# %% [markdown]
# **EJERCICIO:**: Filtra countries con `lifeExp superior a 80` años.

# %%
mask_80 = df_countries['lifeExp'] > 80
mask_80

# %% [markdown]
# PREGUNTA FILTRADO:
# Si en lugar de haber utilizado la variable df_countries, quisiera hacer el filtro cogiendo la variable inicial df...
#
# ¿Sería correcto filtrar de esta forma? En este caso da error porque dice que es Ambiguo.
#
# **mask_80 = df['lifeExp'] > 80 and df['country']== 'Asia'**
# **mask_80**

# %% [markdown]
# ## FILTRAR DATEFRAME (o matriz de datos), con la Máscara.

# %%
df_countries[mask_80]
